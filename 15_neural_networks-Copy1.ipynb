# %% [markdown]
# # From neuron to neural net
#
# Last time, we looked at a single neuron. We discussed the parallels between that neuron with two weights and linear regression. As we add more features (columns in our X matrix), we can add more neurons.
#
# ## Activation Functions
#
# However, as we add neurons, each neuron still mostly functions like linear regression. The next thing we can add to our neuron is an **activation function**. Activation functions adjust the output of a neuron by adding some function before the final output. Below are the "linear" activation function that we have modeled so far, plus the more common **ReLU (Rectified Linear Unit)** and **Sigmoid** activation functions.
#
# ![Diagrams of the linear, ReLU and Sigmoid activation functions](images/Activation_function_diagrams.png)
#
#
# Again, the activation function is applied to the output of a neuron and is a hyperparameter of the model. In practice, while layers may use different activation functions, the same function is applied to **all neurons** of each layer. Below is a single neuron with a couple of possible activation functions.
#
# ![Diagram of a neuron with activation function](images/Activation_function.png)
#
# ## Layers
#
# As we get multiple neurons, we need some way of coordinating their output so we can add a layer to gather the output from multiple neurons into the needed number of outputs (more on that later). However, the other thing that layers do is allow deeper networks with multiple layers, each selected for functional or empirical reasons. This is where deep learning gets its name--as networks grow to have more and more layers of neurons, we refer to them as deep networks--there is no agreed-upon cutoff here...more than three???
#
# ![A two layer neural network](images/Neural_network.png)

# %%
import pandas as pd
import numpy as np
import os
os.environ['KERAS_BACKEND'] = 'torch'
import keras
from keras import layers
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from keras.layers import Dense, Input

# %%
df = pd.read_csv('data/diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Get our X and y
X=df.drop(columns="Outcome")
y=df["Outcome"]

# %%
# Scale data - mean 0 std dev 1
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
# Setup our model
# 1 Dense layer with 8 neurons, 1 Dense layer with 1 neuron and sigmoid
# Sigmoid used for binary classification

model= keras.Sequential([
    layers.Input(shape=(8,)),
    layers.Dense(10, activation="relu"),
    layers.Dense(1, activation='sigmoid')
])
# Print model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 10)             │            90 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 101 (404.00 B)
#  Trainable params: 101 (404.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# Set some model hyperparameters
from keras.optimizers import Adam


lr = 0.001  # Set the learning rate. Start with default for Adam, 0.001
optimizer = Adam(learning_rate=lr)  # Set the optimizer. Start with adam.

# Compile the model--a necessary step with Keras models
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %%
# Now we can fit the model
# Let's also save the training history for plotting

history = model.fit(X,y, epochs=150, validation_split=0.25, batch_size=10, verbose=1)
# Out:
# Epoch 1/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4529 - loss: 0.7678 - val_accuracy: 0.5104 - val_loss: 0.6962
# Epoch 2/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4896 - loss: 0.7250 - val_accuracy: 0.6198 - val_loss: 0.6584
# Epoch 3/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5984 - loss: 0.6748 - val_accuracy: 0.6927 - val_loss: 0.6275
# Epoch 4/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6432 - loss: 0.6489 - val_accuracy: 0.7500 - val_loss: 0.5964
# Epoch 5/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6671 - loss: 0.6222 - val_accuracy: 0.7500 - val_loss: 0.5697
# Epoch 6/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6720 - loss: 0.6034 - val_accuracy: 0.7865 - val_loss: 0.5461
# Epoch 7/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7196 - loss: 0.5547 - val_accuracy: 0.7917 - val_loss: 0.5260
# Epoch 8/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6896 - loss: 0.5728 - val_accuracy: 0.7969 - val_loss: 0.5095
# Epoch 9/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7236 - loss: 0.5237 - val_accuracy: 0.8021 - val_loss: 0.4943
# Epoch 10/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7404 - loss: 0.5045 - val_accuracy: 0.8021 - val_loss: 0.4829
# Epoch 11/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7421 - loss: 0.5023 - val_accuracy: 0.8021 - val_loss: 0.4732
# Epoch 12/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7380 - loss: 0.5070 - val_accuracy: 0.8177 - val_loss: 0.4658
# Epoch 13/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7724 - loss: 0.4670 - val_accuracy: 0.8125 - val_loss: 0.4586
# Epoch 14/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7540 - loss: 0.4866 - val_accuracy: 0.8177 - val_loss: 0.4541
# Epoch 15/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7608 - loss: 0.4723 - val_accuracy: 0.8125 - val_loss: 0.4496
# Epoch 16/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7928 - loss: 0.4543 - val_accuracy: 0.8073 - val_loss: 0.4454
# Epoch 17/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7906 - loss: 0.4552 - val_accuracy: 0.8125 - val_loss: 0.4432
# Epoch 18/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7655 - loss: 0.4718 - val_accuracy: 0.8073 - val_loss: 0.4408
# Epoch 19/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7744 - loss: 0.4774 - val_accuracy: 0.7969 - val_loss: 0.4384
# Epoch 20/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7990 - loss: 0.4446 - val_accuracy: 0.7865 - val_loss: 0.4375
# Epoch 21/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7773 - loss: 0.4518 - val_accuracy: 0.7917 - val_loss: 0.4350
# Epoch 22/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7879 - loss: 0.4383 - val_accuracy: 0.7917 - val_loss: 0.4351
# Epoch 23/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7657 - loss: 0.4682 - val_accuracy: 0.7865 - val_loss: 0.4349
# Epoch 24/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7796 - loss: 0.4507 - val_accuracy: 0.7865 - val_loss: 0.4354
# Epoch 25/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7846 - loss: 0.4488 - val_accuracy: 0.7865 - val_loss: 0.4345
# Epoch 26/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8170 - loss: 0.3942 - val_accuracy: 0.7865 - val_loss: 0.4339
# Epoch 27/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8105 - loss: 0.4120 - val_accuracy: 0.7865 - val_loss: 0.4338
# Epoch 28/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7820 - loss: 0.4524 - val_accuracy: 0.7865 - val_loss: 0.4342
# Epoch 29/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7786 - loss: 0.4605 - val_accuracy: 0.7865 - val_loss: 0.4350
# Epoch 30/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7763 - loss: 0.4545 - val_accuracy: 0.7812 - val_loss: 0.4333
# Epoch 31/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7784 - loss: 0.4493 - val_accuracy: 0.7812 - val_loss: 0.4347
# Epoch 32/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7930 - loss: 0.4691 - val_accuracy: 0.7812 - val_loss: 0.4349
# Epoch 33/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7934 - loss: 0.4267 - val_accuracy: 0.7812 - val_loss: 0.4348
# Epoch 34/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7644 - loss: 0.4537 - val_accuracy: 0.7760 - val_loss: 0.4351
# Epoch 35/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7980 - loss: 0.4490 - val_accuracy: 0.7865 - val_loss: 0.4351
# Epoch 36/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8065 - loss: 0.4255 - val_accuracy: 0.7865 - val_loss: 0.4350
# Epoch 37/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7883 - loss: 0.4292 - val_accuracy: 0.7865 - val_loss: 0.4340
# Epoch 38/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7883 - loss: 0.4489 - val_accuracy: 0.7917 - val_loss: 0.4360
# Epoch 39/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8116 - loss: 0.4248 - val_accuracy: 0.7917 - val_loss: 0.4364
# Epoch 40/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7729 - loss: 0.4693 - val_accuracy: 0.7969 - val_loss: 0.4356
# Epoch 41/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7858 - loss: 0.4615 - val_accuracy: 0.7917 - val_loss: 0.4369
# Epoch 42/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7738 - loss: 0.4637 - val_accuracy: 0.7917 - val_loss: 0.4361
# Epoch 43/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7814 - loss: 0.4403 - val_accuracy: 0.7969 - val_loss: 0.4358
# Epoch 44/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7992 - loss: 0.4441 - val_accuracy: 0.7969 - val_loss: 0.4377
# Epoch 45/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7850 - loss: 0.4476 - val_accuracy: 0.7865 - val_loss: 0.4387
# Epoch 46/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7945 - loss: 0.4490 - val_accuracy: 0.7969 - val_loss: 0.4383
# Epoch 47/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7983 - loss: 0.4349 - val_accuracy: 0.7969 - val_loss: 0.4382
# Epoch 48/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7789 - loss: 0.4462 - val_accuracy: 0.7917 - val_loss: 0.4373
# Epoch 49/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7767 - loss: 0.4774 - val_accuracy: 0.7917 - val_loss: 0.4396
# Epoch 50/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7879 - loss: 0.4572 - val_accuracy: 0.7917 - val_loss: 0.4391
# Epoch 51/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7770 - loss: 0.4659 - val_accuracy: 0.7917 - val_loss: 0.4382
# Epoch 52/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7978 - loss: 0.4235 - val_accuracy: 0.7917 - val_loss: 0.4394
# Epoch 53/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8167 - loss: 0.4358 - val_accuracy: 0.7917 - val_loss: 0.4392
# Epoch 54/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7996 - loss: 0.4466 - val_accuracy: 0.7917 - val_loss: 0.4395
# Epoch 55/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7834 - loss: 0.4351 - val_accuracy: 0.7969 - val_loss: 0.4408
# Epoch 56/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8075 - loss: 0.4148 - val_accuracy: 0.7917 - val_loss: 0.4394
# Epoch 57/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7971 - loss: 0.4326 - val_accuracy: 0.7917 - val_loss: 0.4406
# Epoch 58/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8188 - loss: 0.4017 - val_accuracy: 0.7917 - val_loss: 0.4405
# Epoch 59/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8216 - loss: 0.4099 - val_accuracy: 0.7917 - val_loss: 0.4415
# Epoch 60/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8085 - loss: 0.4140 - val_accuracy: 0.7917 - val_loss: 0.4420
# Epoch 61/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7748 - loss: 0.4585 - val_accuracy: 0.7917 - val_loss: 0.4423
# Epoch 62/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7874 - loss: 0.4493 - val_accuracy: 0.7917 - val_loss: 0.4427
# Epoch 63/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7973 - loss: 0.4262 - val_accuracy: 0.7969 - val_loss: 0.4424
# Epoch 64/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8263 - loss: 0.4137 - val_accuracy: 0.7917 - val_loss: 0.4425
# Epoch 65/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7989 - loss: 0.4352 - val_accuracy: 0.7917 - val_loss: 0.4425
# Epoch 66/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7948 - loss: 0.4283 - val_accuracy: 0.8021 - val_loss: 0.4419
# Epoch 67/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7995 - loss: 0.4245 - val_accuracy: 0.7917 - val_loss: 0.4429
# Epoch 68/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8055 - loss: 0.4130 - val_accuracy: 0.8021 - val_loss: 0.4414
# Epoch 69/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7906 - loss: 0.4338 - val_accuracy: 0.7969 - val_loss: 0.4434
# Epoch 70/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8091 - loss: 0.4259 - val_accuracy: 0.7969 - val_loss: 0.4424
# Epoch 71/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7945 - loss: 0.4336 - val_accuracy: 0.7969 - val_loss: 0.4430
# Epoch 72/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7895 - loss: 0.4176 - val_accuracy: 0.7969 - val_loss: 0.4420
# Epoch 73/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8037 - loss: 0.4232 - val_accuracy: 0.7969 - val_loss: 0.4435
# Epoch 74/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8123 - loss: 0.4038 - val_accuracy: 0.7969 - val_loss: 0.4425
# Epoch 75/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7867 - loss: 0.4440 - val_accuracy: 0.8021 - val_loss: 0.4428
# Epoch 76/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8205 - loss: 0.4136 - val_accuracy: 0.8021 - val_loss: 0.4434
# Epoch 77/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7808 - loss: 0.4389 - val_accuracy: 0.8021 - val_loss: 0.4430
# Epoch 78/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8127 - loss: 0.4053 - val_accuracy: 0.7969 - val_loss: 0.4429
# Epoch 79/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7995 - loss: 0.4209 - val_accuracy: 0.8021 - val_loss: 0.4439
# Epoch 80/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7995 - loss: 0.4309 - val_accuracy: 0.8073 - val_loss: 0.4440
# Epoch 81/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8009 - loss: 0.4255 - val_accuracy: 0.8021 - val_loss: 0.4435
# Epoch 82/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8231 - loss: 0.3909 - val_accuracy: 0.7969 - val_loss: 0.4431
# Epoch 83/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8169 - loss: 0.4349 - val_accuracy: 0.8073 - val_loss: 0.4434
# Epoch 84/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7932 - loss: 0.4365 - val_accuracy: 0.8125 - val_loss: 0.4444
# Epoch 85/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7978 - loss: 0.4561 - val_accuracy: 0.8073 - val_loss: 0.4451
# Epoch 86/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8145 - loss: 0.4146 - val_accuracy: 0.8021 - val_loss: 0.4455
# Epoch 87/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7774 - loss: 0.4363 - val_accuracy: 0.8021 - val_loss: 0.4453
# Epoch 88/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8006 - loss: 0.4251 - val_accuracy: 0.8073 - val_loss: 0.4442
# Epoch 89/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8028 - loss: 0.4271 - val_accuracy: 0.8073 - val_loss: 0.4444
# Epoch 90/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7997 - loss: 0.4165 - val_accuracy: 0.8073 - val_loss: 0.4442
# Epoch 91/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8009 - loss: 0.4204 - val_accuracy: 0.8073 - val_loss: 0.4450
# Epoch 92/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8036 - loss: 0.4212 - val_accuracy: 0.8073 - val_loss: 0.4450
# Epoch 93/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7688 - loss: 0.4510 - val_accuracy: 0.8177 - val_loss: 0.4458
# Epoch 94/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7799 - loss: 0.4360 - val_accuracy: 0.8177 - val_loss: 0.4458
# Epoch 95/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7842 - loss: 0.4408 - val_accuracy: 0.8073 - val_loss: 0.4450
# Epoch 96/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8095 - loss: 0.4002 - val_accuracy: 0.8177 - val_loss: 0.4466
# Epoch 97/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8025 - loss: 0.3992 - val_accuracy: 0.8125 - val_loss: 0.4449
# Epoch 98/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8191 - loss: 0.3960 - val_accuracy: 0.8229 - val_loss: 0.4475
# Epoch 99/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7943 - loss: 0.4203 - val_accuracy: 0.8177 - val_loss: 0.4472
# Epoch 100/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7881 - loss: 0.4486 - val_accuracy: 0.8125 - val_loss: 0.4478
# Epoch 101/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7952 - loss: 0.4064 - val_accuracy: 0.8177 - val_loss: 0.4489
# Epoch 102/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8098 - loss: 0.4176 - val_accuracy: 0.8125 - val_loss: 0.4463
# Epoch 103/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8002 - loss: 0.4085 - val_accuracy: 0.8073 - val_loss: 0.4475
# Epoch 104/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7443 - loss: 0.4994 - val_accuracy: 0.8125 - val_loss: 0.4490
# Epoch 105/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7818 - loss: 0.4262 - val_accuracy: 0.8073 - val_loss: 0.4487
# Epoch 106/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7970 - loss: 0.4118 - val_accuracy: 0.8125 - val_loss: 0.4486
# Epoch 107/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7838 - loss: 0.4300 - val_accuracy: 0.8073 - val_loss: 0.4492
# Epoch 108/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7794 - loss: 0.4453 - val_accuracy: 0.8125 - val_loss: 0.4488
# Epoch 109/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7832 - loss: 0.4321 - val_accuracy: 0.8125 - val_loss: 0.4497
# Epoch 110/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7756 - loss: 0.4303 - val_accuracy: 0.8125 - val_loss: 0.4499
# Epoch 111/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7801 - loss: 0.4470 - val_accuracy: 0.8073 - val_loss: 0.4495
# Epoch 112/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7636 - loss: 0.4689 - val_accuracy: 0.8073 - val_loss: 0.4500
# Epoch 113/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7646 - loss: 0.4507 - val_accuracy: 0.8073 - val_loss: 0.4500
# Epoch 114/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7906 - loss: 0.4358 - val_accuracy: 0.8073 - val_loss: 0.4497
# Epoch 115/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8039 - loss: 0.4310 - val_accuracy: 0.8125 - val_loss: 0.4510
# Epoch 116/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7866 - loss: 0.4392 - val_accuracy: 0.8125 - val_loss: 0.4505
# Epoch 117/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7847 - loss: 0.4453 - val_accuracy: 0.8073 - val_loss: 0.4504
# Epoch 118/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8058 - loss: 0.4068 - val_accuracy: 0.8073 - val_loss: 0.4504
# Epoch 119/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8003 - loss: 0.4153 - val_accuracy: 0.8021 - val_loss: 0.4501
# Epoch 120/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7989 - loss: 0.4279 - val_accuracy: 0.8021 - val_loss: 0.4499
# Epoch 121/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8123 - loss: 0.3933 - val_accuracy: 0.8073 - val_loss: 0.4506
# Epoch 122/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7703 - loss: 0.4455 - val_accuracy: 0.8073 - val_loss: 0.4514
# Epoch 123/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8282 - loss: 0.4052 - val_accuracy: 0.8073 - val_loss: 0.4527
# Epoch 124/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7727 - loss: 0.4645 - val_accuracy: 0.8125 - val_loss: 0.4514
# Epoch 125/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8088 - loss: 0.4023 - val_accuracy: 0.8073 - val_loss: 0.4519
# Epoch 126/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7740 - loss: 0.4538 - val_accuracy: 0.8073 - val_loss: 0.4510
# Epoch 127/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7943 - loss: 0.4207 - val_accuracy: 0.8125 - val_loss: 0.4515
# Epoch 128/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8142 - loss: 0.4164 - val_accuracy: 0.8073 - val_loss: 0.4510
# Epoch 129/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7657 - loss: 0.4533 - val_accuracy: 0.8073 - val_loss: 0.4526
# Epoch 130/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8086 - loss: 0.4159 - val_accuracy: 0.8073 - val_loss: 0.4521
# Epoch 131/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8023 - loss: 0.4113 - val_accuracy: 0.8125 - val_loss: 0.4525
# Epoch 132/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7754 - loss: 0.4340 - val_accuracy: 0.8073 - val_loss: 0.4512
# Epoch 133/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7893 - loss: 0.4426 - val_accuracy: 0.8073 - val_loss: 0.4523
# Epoch 134/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8093 - loss: 0.3914 - val_accuracy: 0.8073 - val_loss: 0.4506
# Epoch 135/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7953 - loss: 0.4218 - val_accuracy: 0.8125 - val_loss: 0.4525
# Epoch 136/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7845 - loss: 0.4355 - val_accuracy: 0.8125 - val_loss: 0.4530
# Epoch 137/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7627 - loss: 0.4489 - val_accuracy: 0.8073 - val_loss: 0.4528
# Epoch 138/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7668 - loss: 0.4340 - val_accuracy: 0.8073 - val_loss: 0.4534
# Epoch 139/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7931 - loss: 0.4102 - val_accuracy: 0.8073 - val_loss: 0.4530
# Epoch 140/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7939 - loss: 0.4256 - val_accuracy: 0.8073 - val_loss: 0.4527
# Epoch 141/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7660 - loss: 0.4329 - val_accuracy: 0.8021 - val_loss: 0.4533
# Epoch 142/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7909 - loss: 0.4301 - val_accuracy: 0.8073 - val_loss: 0.4541
# Epoch 143/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8009 - loss: 0.4165 - val_accuracy: 0.8073 - val_loss: 0.4527
# Epoch 144/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7902 - loss: 0.4287 - val_accuracy: 0.8021 - val_loss: 0.4532
# Epoch 145/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7886 - loss: 0.4365 - val_accuracy: 0.8021 - val_loss: 0.4532
# Epoch 146/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7587 - loss: 0.4483 - val_accuracy: 0.8021 - val_loss: 0.4530
# Epoch 147/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7740 - loss: 0.4332 - val_accuracy: 0.8073 - val_loss: 0.4536
# Epoch 148/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7985 - loss: 0.4080 - val_accuracy: 0.8021 - val_loss: 0.4528
# Epoch 149/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7853 - loss: 0.4254 - val_accuracy: 0.8073 - val_loss: 0.4540
# Epoch 150/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7936 - loss: 0.4247 - val_accuracy: 0.8021 - val_loss: 0.4528

# %%
# Make some nice plots

from matplotlib import pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# # Experimentation
#
# Using what you know so far, try to make the best possible model to predict diabetes with these data.
#
# Things to try:
#
# * Try normalizing data (all values between 0 and 1)
#     ```python
#     # Normalize data - all between 0 and 1
#     scaler = MinMaxScaler()
#     X = scaler.fit_transform(X)
#     ```
# * Adding layers
# * Adjusting the number of neurons per layer (you do need to get back to 1 with a sigmoid activation at the end)
# * Different activation functions
# * Adjusting the number of epochs
# * Adjusting learning rate
