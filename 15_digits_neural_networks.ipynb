# %% [markdown]
# # From neuron to neural net
#
# Last time, we looked at a single neuron. We discussed the parallels between that neuron with two weights and linear regression. As we add more features (columns in our X matrix), we can add more neurons.
#
# ## Activation Functions
#
# However, as we add neurons, each neuron still mostly functions like linear regression. The next thing we can add to our neuron is an **activation function**. Activation functions adjust the output of a neuron by adding some function before the final output. Below are the "linear" activation function that we have modeled so far, plus the more common **ReLU (Rectified Linear Unit)** and **Sigmoid** activation functions.
#
# ![Diagrams of the linear, ReLU and Sigmoid activation functions](images/Activation_function_diagrams.png)
#
#
# Again, the activation function is applied to the output of a neuron and is a hyperparameter of the model. In practice, while layers may use different activation functions, the same function is applied to **all neurons** of each layer. Below is a single neuron with a couple of possible activation functions.
#
# ![Diagram of a neuron with activation function](images/Activation_function.png)
#
# ## Layers
#
# As we get multiple neurons, we need some way of coordinating their output so we can add a layer to gather the output from multiple neurons into the needed number of outputs (more on that later). However, the other thing that layers do is allow deeper networks with multiple layers, each selected for functional or empirical reasons. This is where deep learning gets its name--as networks grow to have more and more layers of neurons, we refer to them as deep networks--there is no agreed-upon cutoff here...more than three???
#
# ![A two layer neural network](images/Neural_network.png)

# %%
import pandas as pd
import numpy as np
import os
os.environ['KERAS_BACKEND'] = 'torch'
import keras
from keras import layers
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from keras.layers import Dense, Input

# %%
from sklearn.datasets import load_digits

digits = load_digits()
digits.data.shape
# Out:
# (1797, 64)

# %%
print(digits.keys())
# Out:
# dict_keys(['data', 'target', 'frame', 'feature_names', 'target_names', 'images', 'DESCR'])

# %%
digits.data[0]
# Out:
# array([ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.,  0.,  0., 13., 15., 10.,
#        15.,  5.,  0.,  0.,  3., 15.,  2.,  0., 11.,  8.,  0.,  0.,  4.,
#        12.,  0.,  0.,  8.,  8.,  0.,  0.,  5.,  8.,  0.,  0.,  9.,  8.,
#         0.,  0.,  4., 11.,  0.,  1., 12.,  7.,  0.,  0.,  2., 14.,  5.,
#        10., 12.,  0.,  0.,  0.,  0.,  6., 13., 10.,  0.,  0.,  0.])

# %%
# Get our X and y
X = digits.data /16
y = digits.target

# %%
# Scale data - mean 0 std dev 1
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
# Setup our model
# 1 Dense layer with 8 neurons, 1 Dense layer with 1 neuron and sigmoid
# Sigmoid used for binary classification

model= keras.Sequential([
    layers.Input(shape=(64,)),
    layers.Dense(10, activation="relu"),
    layers.Dense(10, activation='sigmoid')
])
# Print model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 10)             │           650 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           110 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 760 (2.97 KB)
#  Trainable params: 760 (2.97 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Set some model hyperparameters
from keras.optimizers import Adam


lr = 0.001  # Set the learning rate. Start with default for Adam, 0.001
optimizer = Adam(learning_rate=lr)  # Set the optimizer. Start with adam.

# Compile the model--a necessary step with Keras models
model.compile(loss='crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %%
# Now we can fit the model
# Let's also save the training history for plotting

history = model.fit(X,y, epochs=150, validation_split=0.25, batch_size=10, verbose=1)
# Out:
# Epoch 1/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1660 - loss: 2.2043 - val_accuracy: 0.3267 - val_loss: 1.9264
# Epoch 2/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4902 - loss: 1.7611 - val_accuracy: 0.5244 - val_loss: 1.5677
# Epoch 3/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6131 - loss: 1.3888 - val_accuracy: 0.6422 - val_loss: 1.1840
# Epoch 4/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7082 - loss: 1.0196 - val_accuracy: 0.7600 - val_loss: 0.8833
# Epoch 5/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8255 - loss: 0.6948 - val_accuracy: 0.8289 - val_loss: 0.6861
# Epoch 6/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8877 - loss: 0.4798 - val_accuracy: 0.8489 - val_loss: 0.5652
# Epoch 7/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9211 - loss: 0.3474 - val_accuracy: 0.8622 - val_loss: 0.4948
# Epoch 8/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9440 - loss: 0.2551 - val_accuracy: 0.8689 - val_loss: 0.4578
# Epoch 9/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9563 - loss: 0.1989 - val_accuracy: 0.8733 - val_loss: 0.4341
# Epoch 10/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9580 - loss: 0.1792 - val_accuracy: 0.8800 - val_loss: 0.4138
# Epoch 11/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9500 - loss: 0.1563 - val_accuracy: 0.8778 - val_loss: 0.4025
# Epoch 12/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9753 - loss: 0.1226 - val_accuracy: 0.8822 - val_loss: 0.3955
# Epoch 13/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9739 - loss: 0.1130 - val_accuracy: 0.8822 - val_loss: 0.3905
# Epoch 14/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9705 - loss: 0.1072 - val_accuracy: 0.8889 - val_loss: 0.3856
# Epoch 15/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9785 - loss: 0.0911 - val_accuracy: 0.8867 - val_loss: 0.3826
# Epoch 16/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9837 - loss: 0.0775 - val_accuracy: 0.8867 - val_loss: 0.3773
# Epoch 17/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9826 - loss: 0.0767 - val_accuracy: 0.8889 - val_loss: 0.3781
# Epoch 18/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9822 - loss: 0.0729 - val_accuracy: 0.8889 - val_loss: 0.3745
# Epoch 19/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9765 - loss: 0.0756 - val_accuracy: 0.8889 - val_loss: 0.3734
# Epoch 20/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9808 - loss: 0.0668 - val_accuracy: 0.8911 - val_loss: 0.3681
# Epoch 21/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9867 - loss: 0.0632 - val_accuracy: 0.8911 - val_loss: 0.3692
# Epoch 22/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9861 - loss: 0.0579 - val_accuracy: 0.8911 - val_loss: 0.3688
# Epoch 23/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9837 - loss: 0.0599 - val_accuracy: 0.8933 - val_loss: 0.3670
# Epoch 24/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9871 - loss: 0.0485 - val_accuracy: 0.8933 - val_loss: 0.3647
# Epoch 25/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9926 - loss: 0.0386 - val_accuracy: 0.8933 - val_loss: 0.3679
# Epoch 26/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9852 - loss: 0.0513 - val_accuracy: 0.8956 - val_loss: 0.3584
# Epoch 27/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9937 - loss: 0.0365 - val_accuracy: 0.8956 - val_loss: 0.3634
# Epoch 28/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9847 - loss: 0.0479 - val_accuracy: 0.8956 - val_loss: 0.3578
# Epoch 29/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9915 - loss: 0.0354 - val_accuracy: 0.8978 - val_loss: 0.3585
# Epoch 30/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9939 - loss: 0.0351 - val_accuracy: 0.8978 - val_loss: 0.3522
# Epoch 31/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9959 - loss: 0.0377 - val_accuracy: 0.9022 - val_loss: 0.3526
# Epoch 32/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9966 - loss: 0.0301 - val_accuracy: 0.8978 - val_loss: 0.3488
# Epoch 33/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9943 - loss: 0.0303 - val_accuracy: 0.9000 - val_loss: 0.3494
# Epoch 34/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9984 - loss: 0.0258 - val_accuracy: 0.9000 - val_loss: 0.3519
# Epoch 35/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9955 - loss: 0.0258 - val_accuracy: 0.8978 - val_loss: 0.3480
# Epoch 36/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9963 - loss: 0.0255 - val_accuracy: 0.9000 - val_loss: 0.3449
# Epoch 37/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9977 - loss: 0.0208 - val_accuracy: 0.9022 - val_loss: 0.3457
# Epoch 38/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9974 - loss: 0.0206 - val_accuracy: 0.9000 - val_loss: 0.3477
# Epoch 39/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9975 - loss: 0.0220 - val_accuracy: 0.9000 - val_loss: 0.3479
# Epoch 40/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9978 - loss: 0.0191 - val_accuracy: 0.9000 - val_loss: 0.3465
# Epoch 41/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9989 - loss: 0.0170 - val_accuracy: 0.9000 - val_loss: 0.3458
# Epoch 42/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9978 - loss: 0.0169 - val_accuracy: 0.9022 - val_loss: 0.3462
# Epoch 43/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9958 - loss: 0.0185 - val_accuracy: 0.9000 - val_loss: 0.3494
# Epoch 44/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9992 - loss: 0.0143 - val_accuracy: 0.9000 - val_loss: 0.3467
# Epoch 45/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9980 - loss: 0.0133 - val_accuracy: 0.9022 - val_loss: 0.3449
# Epoch 46/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9989 - loss: 0.0132 - val_accuracy: 0.9022 - val_loss: 0.3438
# Epoch 47/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9974 - loss: 0.0125 - val_accuracy: 0.9067 - val_loss: 0.3486
# Epoch 48/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9991 - loss: 0.0112 - val_accuracy: 0.9067 - val_loss: 0.3482
# Epoch 49/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9991 - loss: 0.0097 - val_accuracy: 0.9044 - val_loss: 0.3498
# Epoch 50/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9991 - loss: 0.0095 - val_accuracy: 0.9067 - val_loss: 0.3550
# Epoch 51/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9973 - loss: 0.0102 - val_accuracy: 0.9089 - val_loss: 0.3508
# Epoch 52/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9979 - loss: 0.0103 - val_accuracy: 0.9089 - val_loss: 0.3544
# Epoch 53/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9996 - loss: 0.0079 - val_accuracy: 0.9044 - val_loss: 0.3577
# Epoch 54/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9995 - loss: 0.0076 - val_accuracy: 0.9067 - val_loss: 0.3573
# Epoch 55/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9981 - loss: 0.0081 - val_accuracy: 0.9067 - val_loss: 0.3620
# Epoch 56/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9969 - loss: 0.0084 - val_accuracy: 0.9067 - val_loss: 0.3610
# Epoch 57/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9984 - loss: 0.0073 - val_accuracy: 0.9111 - val_loss: 0.3651
# Epoch 58/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9989 - loss: 0.0072 - val_accuracy: 0.9089 - val_loss: 0.3641
# Epoch 59/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9981 - loss: 0.0069 - val_accuracy: 0.9067 - val_loss: 0.3688
# Epoch 60/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9989 - loss: 0.0063 - val_accuracy: 0.9067 - val_loss: 0.3676
# Epoch 61/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9989 - loss: 0.0063 - val_accuracy: 0.9133 - val_loss: 0.3729
# Epoch 62/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9979 - loss: 0.0062 - val_accuracy: 0.9089 - val_loss: 0.3728
# Epoch 63/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9979 - loss: 0.0066 - val_accuracy: 0.9111 - val_loss: 0.3746
# Epoch 64/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9997 - loss: 0.0047 - val_accuracy: 0.9111 - val_loss: 0.3764
# Epoch 65/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9969 - loss: 0.0060 - val_accuracy: 0.9133 - val_loss: 0.3781
# Epoch 66/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9984 - loss: 0.0055 - val_accuracy: 0.9111 - val_loss: 0.3799
# Epoch 67/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9961 - loss: 0.0067 - val_accuracy: 0.9133 - val_loss: 0.3827
# Epoch 68/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9970 - loss: 0.0058 - val_accuracy: 0.9111 - val_loss: 0.3845
# Epoch 69/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9990 - loss: 0.0040 - val_accuracy: 0.9089 - val_loss: 0.3880
# Epoch 70/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9986 - loss: 0.0038 - val_accuracy: 0.9133 - val_loss: 0.3917
# Epoch 71/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9988 - loss: 0.0038 - val_accuracy: 0.9111 - val_loss: 0.3934
# Epoch 72/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9993 - loss: 0.0030 - val_accuracy: 0.9067 - val_loss: 0.3964
# Epoch 73/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9970 - loss: 0.0048 - val_accuracy: 0.9111 - val_loss: 0.4010
# Epoch 74/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9985 - loss: 0.0035 - val_accuracy: 0.9089 - val_loss: 0.4000
# Epoch 75/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9987 - loss: 0.0033 - val_accuracy: 0.9111 - val_loss: 0.4021
# Epoch 76/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9980 - loss: 0.0037 - val_accuracy: 0.9067 - val_loss: 0.4068
# Epoch 77/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9971 - loss: 0.0043 - val_accuracy: 0.9111 - val_loss: 0.4097
# Epoch 78/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9979 - loss: 0.0035 - val_accuracy: 0.9089 - val_loss: 0.4139
# Epoch 79/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9985 - loss: 0.0031 - val_accuracy: 0.9089 - val_loss: 0.4190
# Epoch 80/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9989 - loss: 0.0027 - val_accuracy: 0.9067 - val_loss: 0.4172
# Epoch 81/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9990 - loss: 0.0025 - val_accuracy: 0.9089 - val_loss: 0.4201
# Epoch 82/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9989 - loss: 0.0024 - val_accuracy: 0.9089 - val_loss: 0.4245
# Epoch 83/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9993 - loss: 0.0021 - val_accuracy: 0.9044 - val_loss: 0.4240
# Epoch 84/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9981 - loss: 0.0028 - val_accuracy: 0.9067 - val_loss: 0.4296
# Epoch 85/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9986 - loss: 0.0025 - val_accuracy: 0.9067 - val_loss: 0.4289
# Epoch 86/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9989 - loss: 0.0020 - val_accuracy: 0.9067 - val_loss: 0.4355
# Epoch 87/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9945 - loss: 0.0051 - val_accuracy: 0.9067 - val_loss: 0.4373
# Epoch 88/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9994 - loss: 0.0017 - val_accuracy: 0.9089 - val_loss: 0.4379
# Epoch 89/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9984 - loss: 0.0023 - val_accuracy: 0.9067 - val_loss: 0.4409
# Epoch 90/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9984 - loss: 0.0021 - val_accuracy: 0.9067 - val_loss: 0.4422
# Epoch 91/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9993 - loss: 0.0014 - val_accuracy: 0.9067 - val_loss: 0.4432
# Epoch 92/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9978 - loss: 0.0026 - val_accuracy: 0.9089 - val_loss: 0.4505
# Epoch 93/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9993 - loss: 0.0014 - val_accuracy: 0.9022 - val_loss: 0.4526
# Epoch 94/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9982 - loss: 0.0022 - val_accuracy: 0.9067 - val_loss: 0.4608
# Epoch 95/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9977 - loss: 0.0024 - val_accuracy: 0.9067 - val_loss: 0.4585
# Epoch 96/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9993 - loss: 0.0013 - val_accuracy: 0.9089 - val_loss: 0.4617
# Epoch 97/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9983 - loss: 0.0020 - val_accuracy: 0.9089 - val_loss: 0.4635
# Epoch 98/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9992 - loss: 0.0012 - val_accuracy: 0.9067 - val_loss: 0.4658
# Epoch 99/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9994 - loss: 9.8892e-04 - val_accuracy: 0.9067 - val_loss: 0.4700
# Epoch 100/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9980 - loss: 0.0020 - val_accuracy: 0.9067 - val_loss: 0.4736
# Epoch 101/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9987 - loss: 0.0014 - val_accuracy: 0.9067 - val_loss: 0.4786
# Epoch 102/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9961 - loss: 0.0033 - val_accuracy: 0.9067 - val_loss: 0.4765
# Epoch 103/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9991 - loss: 0.0011 - val_accuracy: 0.9067 - val_loss: 0.4804
# Epoch 104/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9978 - loss: 0.0020 - val_accuracy: 0.9067 - val_loss: 0.4854
# Epoch 105/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9983 - loss: 0.0017 - val_accuracy: 0.9111 - val_loss: 0.4878
# Epoch 106/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9990 - loss: 0.0011 - val_accuracy: 0.9067 - val_loss: 0.4869
# Epoch 107/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9974 - loss: 0.0022 - val_accuracy: 0.9067 - val_loss: 0.4908
# Epoch 108/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9990 - loss: 0.0011 - val_accuracy: 0.9067 - val_loss: 0.4981
# Epoch 109/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9988 - loss: 0.0012 - val_accuracy: 0.9067 - val_loss: 0.4975
# Epoch 110/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9984 - loss: 0.0014 - val_accuracy: 0.9067 - val_loss: 0.5002
# Epoch 111/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9992 - loss: 9.0121e-04 - val_accuracy: 0.9111 - val_loss: 0.5004
# Epoch 112/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9990 - loss: 0.0010 - val_accuracy: 0.9067 - val_loss: 0.5047
# Epoch 113/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9988 - loss: 0.0011 - val_accuracy: 0.9067 - val_loss: 0.5115
# Epoch 114/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9990 - loss: 0.0010 - val_accuracy: 0.9067 - val_loss: 0.5113
# Epoch 115/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9989 - loss: 0.0010 - val_accuracy: 0.9067 - val_loss: 0.5189
# Epoch 116/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9990 - loss: 9.2662e-04 - val_accuracy: 0.9067 - val_loss: 0.5232
# Epoch 117/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9995 - loss: 5.6900e-04 - val_accuracy: 0.9067 - val_loss: 0.5242
# Epoch 118/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9995 - loss: 5.3678e-04 - val_accuracy: 0.9089 - val_loss: 0.5255
# Epoch 119/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9985 - loss: 0.0012 - val_accuracy: 0.9067 - val_loss: 0.5295
# Epoch 120/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9978 - loss: 0.0018 - val_accuracy: 0.9089 - val_loss: 0.5327
# Epoch 121/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9981 - loss: 0.0015 - val_accuracy: 0.9067 - val_loss: 0.5342
# Epoch 122/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9990 - loss: 8.4465e-04 - val_accuracy: 0.9067 - val_loss: 0.5354
# Epoch 123/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9991 - loss: 7.5161e-04 - val_accuracy: 0.9067 - val_loss: 0.5389
# Epoch 124/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9985 - loss: 0.0012 - val_accuracy: 0.9089 - val_loss: 0.5389
# Epoch 125/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9973 - loss: 0.0020 - val_accuracy: 0.9089 - val_loss: 0.5427
# Epoch 126/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9995 - loss: 4.9602e-04 - val_accuracy: 0.9089 - val_loss: 0.5433
# Epoch 127/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9988 - loss: 9.2993e-04 - val_accuracy: 0.9089 - val_loss: 0.5495
# Epoch 128/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9979 - loss: 0.0016 - val_accuracy: 0.9067 - val_loss: 0.5520
# Epoch 129/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9964 - loss: 0.0026 - val_accuracy: 0.9089 - val_loss: 0.5573
# Epoch 130/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9965 - loss: 0.0026 - val_accuracy: 0.9089 - val_loss: 0.5584
# Epoch 131/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9997 - loss: 3.1466e-04 - val_accuracy: 0.9067 - val_loss: 0.5603
# Epoch 132/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9987 - loss: 0.0010 - val_accuracy: 0.9111 - val_loss: 0.5601
# Epoch 133/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9989 - loss: 8.7196e-04 - val_accuracy: 0.9089 - val_loss: 0.5666
# Epoch 134/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9983 - loss: 0.0013 - val_accuracy: 0.9089 - val_loss: 0.5689
# Epoch 135/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9996 - loss: 3.8731e-04 - val_accuracy: 0.9111 - val_loss: 0.5749
# Epoch 136/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9971 - loss: 0.0021 - val_accuracy: 0.9067 - val_loss: 0.5762
# Epoch 137/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9983 - loss: 0.0012 - val_accuracy: 0.9089 - val_loss: 0.5785
# Epoch 138/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9970 - loss: 0.0022 - val_accuracy: 0.9089 - val_loss: 0.5790
# Epoch 139/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9992 - loss: 6.4330e-04 - val_accuracy: 0.9111 - val_loss: 0.5825
# Epoch 140/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9991 - loss: 6.7015e-04 - val_accuracy: 0.9111 - val_loss: 0.5835
# Epoch 141/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9974 - loss: 0.0019 - val_accuracy: 0.9089 - val_loss: 0.5872
# Epoch 142/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9968 - loss: 0.0023 - val_accuracy: 0.9111 - val_loss: 0.5920
# Epoch 143/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9980 - loss: 0.0015 - val_accuracy: 0.9111 - val_loss: 0.5927
# Epoch 144/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9992 - loss: 5.8675e-04 - val_accuracy: 0.9111 - val_loss: 0.5980
# Epoch 145/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9973 - loss: 0.0019 - val_accuracy: 0.9133 - val_loss: 0.6014
# Epoch 146/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9974 - loss: 0.0018 - val_accuracy: 0.9133 - val_loss: 0.6017
# Epoch 147/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9978 - loss: 0.0016 - val_accuracy: 0.9133 - val_loss: 0.6050
# Epoch 148/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9988 - loss: 8.3914e-04 - val_accuracy: 0.9133 - val_loss: 0.6070
# Epoch 149/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9974 - loss: 0.0018 - val_accuracy: 0.9111 - val_loss: 0.6109
# Epoch 150/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9988 - loss: 8.8765e-04 - val_accuracy: 0.9111 - val_loss: 0.6161

# %%
# Make some nice plots

from matplotlib import pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# # Experimentation
#
# Using what you know so far, try to make the best possible model to predict diabetes with these data.
#
# Things to try:
#
# * Try normalizing data (all values between 0 and 1)
#     ```python
#     # Normalize data - all between 0 and 1
#     scaler = MinMaxScaler()
#     X = scaler.fit_transform(X)
#     ```
# * Adding layers
# * Adjusting the number of neurons per layer (you do need to get back to 1 with a sigmoid activation at the end)
# * Different activation functions
# * Adjusting the number of epochs
# * Adjusting learning rate

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np
import matplotlin.pyplot as plt

cm = confusion_matrix(y_test
