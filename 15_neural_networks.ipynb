# %% [markdown]
# # From neuron to neural net
#
# Last time, we looked at a single neuron. We discussed the parallels between that neuron with two weights and linear regression. As we add more features (columns in our X matrix), we can add more neurons.
#
# ## Activation Functions
#
# However, as we add neurons, each neuron still mostly functions like linear regression. The next thing we can add to our neuron is an **activation function**. Activation functions adjust the output of a neuron by adding some function before the final output. Below are the "linear" activation function that we have modeled so far, plus the more common **ReLU (Rectified Linear Unit)** and **Sigmoid** activation functions.
#
# ![Diagrams of the linear, ReLU and Sigmoid activation functions](images/Activation_function_diagrams.png)
#
#
# Again, the activation function is applied to the output of a neuron and is a hyperparameter of the model. In practice, while layers may use different activation functions, the same function is applied to **all neurons** of each layer. Below is a single neuron with a couple of possible activation functions.
#
# ![Diagram of a neuron with activation function](images/Activation_function.png)
#
# ## Layers
#
# As we get multiple neurons, we need some way of coordinating their output so we can add a layer to gather the output from multiple neurons into the needed number of outputs (more on that later). However, the other thing that layers do is allow deeper networks with multiple layers, each selected for functional or empirical reasons. This is where deep learning gets its name--as networks grow to have more and more layers of neurons, we refer to them as deep networks--there is no agreed-upon cutoff here...more than three???
#
# ![A two layer neural network](images/Neural_network.png)

# %%
import pandas as pd
import numpy as np
import os
os.environ['KERAS_BACKEND'] = 'torch'
import keras
from keras import layers
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from keras.layers import Dense, Input

# %%
df = pd.read_csv('data/diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Get our X and y
X=df.drop(columns="Outcome")
y=df["Outcome"]

# %%
# Scale data - mean 0 std dev 1
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
# Setup our model
# 1 Dense layer with 8 neurons, 1 Dense layer with 1 neuron and sigmoid
# Sigmoid used for binary classification

model= keras.Sequential([
    layers.Input(shape=(8,)),
    layers.Dense(10, activation="relu"),
    layers.Dense(1, activation='sigmoid')
])
# Print model summary
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 10)             │            90 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 101 (404.00 B)
#  Trainable params: 101 (404.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# Set some model hyperparameters
from keras.optimizers import Adam


lr = 0.001  # Set the learning rate. Start with default for Adam, 0.001
optimizer = Adam(learning_rate=lr)  # Set the optimizer. Start with adam.

# Compile the model--a necessary step with Keras models
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %%
# Now we can fit the model
# Let's also save the training history for plotting

history = model.fit(X,y, epochs=150, validation_split=0.25, batch_size=10, verbose=1)
# Out:
# Epoch 1/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4399 - loss: 0.7626 - val_accuracy: 0.6354 - val_loss: 0.6401
# Epoch 2/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6296 - loss: 0.6677 - val_accuracy: 0.7344 - val_loss: 0.5917
# Epoch 3/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6920 - loss: 0.6095 - val_accuracy: 0.7656 - val_loss: 0.5567
# Epoch 4/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7420 - loss: 0.5748 - val_accuracy: 0.8021 - val_loss: 0.5310
# Epoch 5/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7170 - loss: 0.5614 - val_accuracy: 0.8073 - val_loss: 0.5110
# Epoch 6/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7283 - loss: 0.5403 - val_accuracy: 0.8073 - val_loss: 0.4967
# Epoch 7/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7302 - loss: 0.5181 - val_accuracy: 0.8125 - val_loss: 0.4842
# Epoch 8/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7323 - loss: 0.5278 - val_accuracy: 0.8073 - val_loss: 0.4747
# Epoch 9/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7962 - loss: 0.4764 - val_accuracy: 0.8125 - val_loss: 0.4675
# Epoch 10/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7589 - loss: 0.4881 - val_accuracy: 0.8073 - val_loss: 0.4617
# Epoch 11/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7661 - loss: 0.5051 - val_accuracy: 0.8125 - val_loss: 0.4574
# Epoch 12/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7810 - loss: 0.4656 - val_accuracy: 0.8073 - val_loss: 0.4520
# Epoch 13/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7810 - loss: 0.4757 - val_accuracy: 0.8073 - val_loss: 0.4496
# Epoch 14/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7541 - loss: 0.4883 - val_accuracy: 0.8073 - val_loss: 0.4473
# Epoch 15/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7879 - loss: 0.4505 - val_accuracy: 0.8021 - val_loss: 0.4461
# Epoch 16/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7672 - loss: 0.4704 - val_accuracy: 0.8021 - val_loss: 0.4447
# Epoch 17/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7530 - loss: 0.4958 - val_accuracy: 0.8021 - val_loss: 0.4432
# Epoch 18/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7950 - loss: 0.4700 - val_accuracy: 0.8021 - val_loss: 0.4418
# Epoch 19/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7684 - loss: 0.4803 - val_accuracy: 0.8021 - val_loss: 0.4415
# Epoch 20/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7849 - loss: 0.4524 - val_accuracy: 0.8021 - val_loss: 0.4409
# Epoch 21/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7840 - loss: 0.4518 - val_accuracy: 0.8021 - val_loss: 0.4400
# Epoch 22/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7583 - loss: 0.4932 - val_accuracy: 0.8073 - val_loss: 0.4408
# Epoch 23/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7752 - loss: 0.4657 - val_accuracy: 0.8073 - val_loss: 0.4399
# Epoch 24/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7785 - loss: 0.4534 - val_accuracy: 0.8073 - val_loss: 0.4407
# Epoch 25/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7589 - loss: 0.4769 - val_accuracy: 0.8073 - val_loss: 0.4402
# Epoch 26/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7914 - loss: 0.4534 - val_accuracy: 0.8073 - val_loss: 0.4413
# Epoch 27/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7743 - loss: 0.4579 - val_accuracy: 0.8021 - val_loss: 0.4397
# Epoch 28/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7633 - loss: 0.4797 - val_accuracy: 0.8073 - val_loss: 0.4404
# Epoch 29/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7740 - loss: 0.4765 - val_accuracy: 0.8021 - val_loss: 0.4401
# Epoch 30/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7815 - loss: 0.4684 - val_accuracy: 0.8021 - val_loss: 0.4403
# Epoch 31/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7984 - loss: 0.4367 - val_accuracy: 0.7969 - val_loss: 0.4393
# Epoch 32/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7725 - loss: 0.4866 - val_accuracy: 0.7969 - val_loss: 0.4391
# Epoch 33/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7781 - loss: 0.4658 - val_accuracy: 0.8021 - val_loss: 0.4400
# Epoch 34/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7750 - loss: 0.4547 - val_accuracy: 0.7969 - val_loss: 0.4394
# Epoch 35/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7723 - loss: 0.4483 - val_accuracy: 0.8021 - val_loss: 0.4401
# Epoch 36/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7791 - loss: 0.4605 - val_accuracy: 0.8073 - val_loss: 0.4400
# Epoch 37/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7782 - loss: 0.4532 - val_accuracy: 0.8073 - val_loss: 0.4414
# Epoch 38/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7684 - loss: 0.4824 - val_accuracy: 0.8073 - val_loss: 0.4412
# Epoch 39/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7837 - loss: 0.4657 - val_accuracy: 0.8021 - val_loss: 0.4407
# Epoch 40/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7968 - loss: 0.4226 - val_accuracy: 0.7917 - val_loss: 0.4415
# Epoch 41/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7657 - loss: 0.4856 - val_accuracy: 0.7969 - val_loss: 0.4405
# Epoch 42/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7796 - loss: 0.4642 - val_accuracy: 0.7917 - val_loss: 0.4414
# Epoch 43/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7745 - loss: 0.4715 - val_accuracy: 0.8021 - val_loss: 0.4414
# Epoch 44/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7632 - loss: 0.4777 - val_accuracy: 0.7917 - val_loss: 0.4411
# Epoch 45/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7643 - loss: 0.4730 - val_accuracy: 0.7917 - val_loss: 0.4417
# Epoch 46/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7804 - loss: 0.4445 - val_accuracy: 0.7917 - val_loss: 0.4424
# Epoch 47/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7846 - loss: 0.4776 - val_accuracy: 0.8021 - val_loss: 0.4423
# Epoch 48/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8082 - loss: 0.4185 - val_accuracy: 0.7865 - val_loss: 0.4412
# Epoch 49/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8212 - loss: 0.4052 - val_accuracy: 0.7865 - val_loss: 0.4416
# Epoch 50/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7946 - loss: 0.4324 - val_accuracy: 0.7865 - val_loss: 0.4418
# Epoch 51/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7550 - loss: 0.4705 - val_accuracy: 0.7865 - val_loss: 0.4423
# Epoch 52/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8044 - loss: 0.4260 - val_accuracy: 0.7917 - val_loss: 0.4426
# Epoch 53/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7982 - loss: 0.4322 - val_accuracy: 0.7917 - val_loss: 0.4431
# Epoch 54/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7874 - loss: 0.4595 - val_accuracy: 0.7865 - val_loss: 0.4424
# Epoch 55/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7627 - loss: 0.4655 - val_accuracy: 0.7917 - val_loss: 0.4431
# Epoch 56/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7675 - loss: 0.4602 - val_accuracy: 0.7865 - val_loss: 0.4425
# Epoch 57/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7657 - loss: 0.4641 - val_accuracy: 0.7865 - val_loss: 0.4420
# Epoch 58/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7755 - loss: 0.4508 - val_accuracy: 0.7969 - val_loss: 0.4436
# Epoch 59/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7955 - loss: 0.4429 - val_accuracy: 0.7865 - val_loss: 0.4436
# Epoch 60/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8078 - loss: 0.4243 - val_accuracy: 0.7917 - val_loss: 0.4426
# Epoch 61/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7924 - loss: 0.4415 - val_accuracy: 0.7865 - val_loss: 0.4425
# Epoch 62/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7984 - loss: 0.4241 - val_accuracy: 0.7865 - val_loss: 0.4428
# Epoch 63/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7568 - loss: 0.4787 - val_accuracy: 0.7865 - val_loss: 0.4422
# Epoch 64/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7831 - loss: 0.4266 - val_accuracy: 0.7865 - val_loss: 0.4430
# Epoch 65/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7447 - loss: 0.4847 - val_accuracy: 0.7917 - val_loss: 0.4432
# Epoch 66/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8157 - loss: 0.4337 - val_accuracy: 0.7812 - val_loss: 0.4428
# Epoch 67/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7826 - loss: 0.4566 - val_accuracy: 0.7865 - val_loss: 0.4428
# Epoch 68/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7834 - loss: 0.4196 - val_accuracy: 0.7917 - val_loss: 0.4436
# Epoch 69/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8012 - loss: 0.4174 - val_accuracy: 0.7865 - val_loss: 0.4432
# Epoch 70/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7804 - loss: 0.4484 - val_accuracy: 0.7812 - val_loss: 0.4442
# Epoch 71/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7714 - loss: 0.4553 - val_accuracy: 0.7917 - val_loss: 0.4434
# Epoch 72/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7615 - loss: 0.4730 - val_accuracy: 0.7917 - val_loss: 0.4440
# Epoch 73/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8079 - loss: 0.4155 - val_accuracy: 0.7865 - val_loss: 0.4443
# Epoch 74/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7795 - loss: 0.4471 - val_accuracy: 0.7917 - val_loss: 0.4448
# Epoch 75/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7993 - loss: 0.4350 - val_accuracy: 0.7760 - val_loss: 0.4443
# Epoch 76/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7771 - loss: 0.4399 - val_accuracy: 0.7865 - val_loss: 0.4445
# Epoch 77/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7326 - loss: 0.5006 - val_accuracy: 0.7917 - val_loss: 0.4448
# Epoch 78/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7863 - loss: 0.4308 - val_accuracy: 0.7760 - val_loss: 0.4445
# Epoch 79/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7765 - loss: 0.4501 - val_accuracy: 0.7812 - val_loss: 0.4455
# Epoch 80/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7886 - loss: 0.4379 - val_accuracy: 0.7865 - val_loss: 0.4456
# Epoch 81/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7458 - loss: 0.4728 - val_accuracy: 0.7760 - val_loss: 0.4457
# Epoch 82/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7838 - loss: 0.4298 - val_accuracy: 0.7760 - val_loss: 0.4461
# Epoch 83/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7934 - loss: 0.4208 - val_accuracy: 0.7812 - val_loss: 0.4459
# Epoch 84/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7510 - loss: 0.4564 - val_accuracy: 0.7760 - val_loss: 0.4467
# Epoch 85/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7692 - loss: 0.4567 - val_accuracy: 0.7760 - val_loss: 0.4468
# Epoch 86/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8059 - loss: 0.4077 - val_accuracy: 0.7760 - val_loss: 0.4472
# Epoch 87/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7894 - loss: 0.4231 - val_accuracy: 0.7760 - val_loss: 0.4469
# Epoch 88/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7846 - loss: 0.4340 - val_accuracy: 0.7760 - val_loss: 0.4465
# Epoch 89/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7839 - loss: 0.4417 - val_accuracy: 0.7708 - val_loss: 0.4472
# Epoch 90/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7476 - loss: 0.4776 - val_accuracy: 0.7760 - val_loss: 0.4485
# Epoch 91/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7792 - loss: 0.4318 - val_accuracy: 0.7760 - val_loss: 0.4484
# Epoch 92/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8320 - loss: 0.3799 - val_accuracy: 0.7760 - val_loss: 0.4478
# Epoch 93/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7637 - loss: 0.4416 - val_accuracy: 0.7760 - val_loss: 0.4496
# Epoch 94/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7991 - loss: 0.4135 - val_accuracy: 0.7760 - val_loss: 0.4501
# Epoch 95/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7678 - loss: 0.4429 - val_accuracy: 0.7656 - val_loss: 0.4492
# Epoch 96/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8033 - loss: 0.4003 - val_accuracy: 0.7760 - val_loss: 0.4502
# Epoch 97/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7716 - loss: 0.4341 - val_accuracy: 0.7656 - val_loss: 0.4504
# Epoch 98/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7708 - loss: 0.4309 - val_accuracy: 0.7656 - val_loss: 0.4507
# Epoch 99/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8146 - loss: 0.3979 - val_accuracy: 0.7656 - val_loss: 0.4515
# Epoch 100/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7788 - loss: 0.4438 - val_accuracy: 0.7656 - val_loss: 0.4510
# Epoch 101/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7698 - loss: 0.4636 - val_accuracy: 0.7708 - val_loss: 0.4504
# Epoch 102/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7811 - loss: 0.4231 - val_accuracy: 0.7708 - val_loss: 0.4520
# Epoch 103/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7649 - loss: 0.4417 - val_accuracy: 0.7656 - val_loss: 0.4522
# Epoch 104/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7938 - loss: 0.4280 - val_accuracy: 0.7656 - val_loss: 0.4519
# Epoch 105/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8029 - loss: 0.4082 - val_accuracy: 0.7656 - val_loss: 0.4532
# Epoch 106/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7640 - loss: 0.4779 - val_accuracy: 0.7708 - val_loss: 0.4532
# Epoch 107/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7965 - loss: 0.4115 - val_accuracy: 0.7656 - val_loss: 0.4533
# Epoch 108/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7925 - loss: 0.4312 - val_accuracy: 0.7708 - val_loss: 0.4522
# Epoch 109/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7888 - loss: 0.4532 - val_accuracy: 0.7708 - val_loss: 0.4533
# Epoch 110/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7956 - loss: 0.4319 - val_accuracy: 0.7708 - val_loss: 0.4530
# Epoch 111/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8259 - loss: 0.4005 - val_accuracy: 0.7708 - val_loss: 0.4537
# Epoch 112/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7745 - loss: 0.4515 - val_accuracy: 0.7708 - val_loss: 0.4527
# Epoch 113/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8009 - loss: 0.4094 - val_accuracy: 0.7708 - val_loss: 0.4530
# Epoch 114/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7706 - loss: 0.4477 - val_accuracy: 0.7656 - val_loss: 0.4539
# Epoch 115/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7869 - loss: 0.4430 - val_accuracy: 0.7708 - val_loss: 0.4537
# Epoch 116/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7832 - loss: 0.4412 - val_accuracy: 0.7708 - val_loss: 0.4531
# Epoch 117/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7912 - loss: 0.4186 - val_accuracy: 0.7708 - val_loss: 0.4535
# Epoch 118/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8012 - loss: 0.4333 - val_accuracy: 0.7708 - val_loss: 0.4541
# Epoch 119/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7806 - loss: 0.4528 - val_accuracy: 0.7708 - val_loss: 0.4532
# Epoch 120/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7955 - loss: 0.4418 - val_accuracy: 0.7708 - val_loss: 0.4529
# Epoch 121/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8032 - loss: 0.4154 - val_accuracy: 0.7708 - val_loss: 0.4528
# Epoch 122/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7700 - loss: 0.4448 - val_accuracy: 0.7708 - val_loss: 0.4532
# Epoch 123/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7893 - loss: 0.4161 - val_accuracy: 0.7708 - val_loss: 0.4542
# Epoch 124/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7954 - loss: 0.4367 - val_accuracy: 0.7760 - val_loss: 0.4549
# Epoch 125/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7997 - loss: 0.4052 - val_accuracy: 0.7812 - val_loss: 0.4538
# Epoch 126/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8061 - loss: 0.4175 - val_accuracy: 0.7812 - val_loss: 0.4540
# Epoch 127/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7996 - loss: 0.4072 - val_accuracy: 0.7812 - val_loss: 0.4537
# Epoch 128/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8135 - loss: 0.4072 - val_accuracy: 0.7865 - val_loss: 0.4541
# Epoch 129/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7784 - loss: 0.4496 - val_accuracy: 0.7708 - val_loss: 0.4537
# Epoch 130/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7834 - loss: 0.4323 - val_accuracy: 0.7760 - val_loss: 0.4534
# Epoch 131/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8037 - loss: 0.4159 - val_accuracy: 0.7760 - val_loss: 0.4536
# Epoch 132/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7907 - loss: 0.4258 - val_accuracy: 0.7708 - val_loss: 0.4541
# Epoch 133/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8100 - loss: 0.4100 - val_accuracy: 0.7812 - val_loss: 0.4545
# Epoch 134/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7929 - loss: 0.4266 - val_accuracy: 0.7708 - val_loss: 0.4544
# Epoch 135/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7748 - loss: 0.4279 - val_accuracy: 0.7812 - val_loss: 0.4555
# Epoch 136/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7869 - loss: 0.4468 - val_accuracy: 0.7865 - val_loss: 0.4552
# Epoch 137/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8042 - loss: 0.4183 - val_accuracy: 0.7812 - val_loss: 0.4547
# Epoch 138/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8139 - loss: 0.3932 - val_accuracy: 0.7812 - val_loss: 0.4560
# Epoch 139/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7728 - loss: 0.4415 - val_accuracy: 0.7812 - val_loss: 0.4552
# Epoch 140/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7704 - loss: 0.4515 - val_accuracy: 0.7865 - val_loss: 0.4567
# Epoch 141/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8194 - loss: 0.3863 - val_accuracy: 0.7865 - val_loss: 0.4556
# Epoch 142/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7798 - loss: 0.4292 - val_accuracy: 0.7812 - val_loss: 0.4552
# Epoch 143/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8191 - loss: 0.3955 - val_accuracy: 0.7812 - val_loss: 0.4551
# Epoch 144/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7686 - loss: 0.4460 - val_accuracy: 0.7865 - val_loss: 0.4579
# Epoch 145/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7782 - loss: 0.4458 - val_accuracy: 0.7865 - val_loss: 0.4574
# Epoch 146/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8070 - loss: 0.4165 - val_accuracy: 0.7865 - val_loss: 0.4569
# Epoch 147/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8094 - loss: 0.4124 - val_accuracy: 0.7865 - val_loss: 0.4567
# Epoch 148/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7919 - loss: 0.4313 - val_accuracy: 0.7865 - val_loss: 0.4579
# Epoch 149/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8070 - loss: 0.4092 - val_accuracy: 0.7812 - val_loss: 0.4570
# Epoch 150/150
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7865 - loss: 0.4295 - val_accuracy: 0.7812 - val_loss: 0.4584

# %%
# Make some nice plots

from matplotlib import pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# # Experimentation
#
# Using what you know so far, try to make the best possible model to predict diabetes with these data.
#
# Things to try:
#
# * Try normalizing data (all values between 0 and 1)
#     ```python
#     # Normalize data - all between 0 and 1
#     scaler = MinMaxScaler()
#     X = scaler.fit_transform(X)
#     ```
# * Adding layers
# * Adjusting the number of neurons per layer (you do need to get back to 1 with a sigmoid activation at the end)
# * Different activation functions
# * Adjusting the number of epochs
# * Adjusting learning rate
